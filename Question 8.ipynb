# %% [markdown]
# # Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd

hollywood_actor_kills = pd.read_csv('actor_kill_counts.csv')
actor_names = hollywood_actor_kills['Actor'].values
kill_counts = hollywood_actor_kills['Count'].values

df = pd.DataFrame(
   dict(
      actor_names=actor_names,
      kill_counts=kill_counts
   )
)
import matplotlib.pyplot as plt

plt.barh(actor_names,kill_counts)
plt.title('Deadliest Actors in Hollywood')
plt.ylabel('Actor name')
plt.xlabel('Kill Count')
plt.show()

df_sorted = df.sort_values('kill_counts')
plt.barh('actor_names', 'kill_counts', data=df_sorted, color='orange')
plt.ylabel('Actor name')
plt.xlabel('Kill Count')
plt.show()
